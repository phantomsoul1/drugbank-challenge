# %%
from bs4 import BeautifulSoup
from pprint import pprint
import requests

# %%
drug_identifiers = [
    'DB00619',
    'DB01048',
    'DB14093',
    'DB00173',
    'DB00734',
    'DB00218',
    'DB05196',
    'DB09095',
    'DB01053',
    'DB00274'
]
base_url = 'https://www.drugbank.ca/drugs/'

# %%
drugs = []
for identifier in drug_identifiers:
    drugs.append({'drug_bank_id': identifier})
    
print(drugs)
# Out:
# [{'drug_bank_id': 'DB00619'}, {'drug_bank_id': 'DB01048'}, {'drug_bank_id': 'DB14093'}, {'drug_bank_id': 'DB00173'}, {'drug_bank_id': 'DB00734'}, {'drug_bank_id': 'DB00218'}, {'drug_bank_id': 'DB05196'}, {'drug_bank_id': 'DB09095'}, {'drug_bank_id': 'DB01053'}, {'drug_bank_id': 'DB00274'}]

# %%
# Loop through all the drugs in the list
for drug in drugs:
    
    # Build the URL for the current drug and get its document
    url = base_url + drug['drug_bank_id']
    response = requests.get(url)

    # Parse document; using html5lib to ensure tags such as dl, dt, and dd
    # are parsed correctly
    soup = BeautifulSoup(response.text, 'html5lib')

    # SMILES - located in the text of the tag after the tag with id 'smiles'
    try:
        smiles = soup.find(id='smiles').next_sibling.text
        drug['smiles'] = smiles
        
    except AttributeError:
        print(f"{drug['drug_bank_id']}: SMILES not found")

    # TARGETS - located in a list of cards wrapped by a tag with id 'targets'
    try:
        targets = soup.find(id='targets')
        bond_list = targets.find('div', class_='bond-list')
        bond_cards = bond_list.find_all('div', class_='bond card')
        drug['targets'] = []

        # Iterate through all the cards in the list found here
        for bond_card in bond_cards:
            target = {}
            
            target_name = bond_card.find(class_='card-header').find('strong').find('a').text

            # ACTIONS - located within the bond-card in a list of elements in the 
            # tag following a tag with id 'actions'
            try:
                actions = bond_card.find(id='actions').next_sibling.find_all()
                target['actions'] = []
                for action in actions:
                    target['actions'].append(action.text)
            except:
                print(f"{drug['drug_bank_id']}: {target_name}: no actions found")

            # GENE NAME - located within the bond-card in the text of the tag
            # following a tag with id 'gene-name'
            try:
                gene_name = bond_card.find(id='gene-name').next_sibling.text
                target['gene_name'] = gene_name
            except:
                print(f"{drug['drug_bank_id']}: {target_name}: gene name not found")

            if len(target) > 0: 
                drug['targets'].append(target)

    except AttributeError:
        print(f"{drug['drug_bank_id']}: No targets found")

    # ALTERNATIVE IDENTIFIERS - located within a list in the tag following a
    # tag with id 'external-links'. The list is contained within a 'dl' tag
    # that has a series of alternating 'dt' and 'dd' tags that contain each
    # external link's name and value, respectively
    try:
        alt_ids = soup.find(id='external-links').next_sibling
        dts = alt_ids.find('dl').find_all('dt')
        drug['alternative_identifiers'] = {}

        for dt in dts:
            try:
                drug['alternative_identifiers'][dt.text] = dt.next_sibling.text
                
            except AttributeError:
                print(f"{drug['drug_bank_id']}: error scraping alternative identifier")
    
    except AttributeError:
        print(f"{drug['drug_bank_id']}: no alternative identifiers found")
# Out:
# DB01048: No targets found
# DB14093: No targets found
# DB00173: Adenine phosphoribosyltransferase: no actions found
# DB00173: 5'-methylthioadenosine/S-adenosylhomocysteine nucleosidase: no actions found
# DB00173: Acetyl-CoA carboxylase 2: no actions found
# DB00173: Low molecular weight phosphotyrosine protein phosphatase: no actions found
# DB00173: Peroxisomal trans-2-enoyl-CoA reductase: no actions found
# DB00173: A/G-specific adenine glycosylase: no actions found
# DB00173: Nucleoside deoxyribosyltransferase-I: no actions found
# DB00173: SRSF protein kinase 2: no actions found
# DB00173: Holliday junction ATP-dependent DNA helicase RuvB: no actions found
# DB00173: DNA: no actions found
# DB00173: DNA: gene name not found
# DB00173: S-methyl-5'-thioadenosine phosphorylase: no actions found
# DB00173: Nicotinate-nucleotide--dimethylbenzimidazole phosphoribosyltransferase: no actions found
# DB00734: No targets found
# DB05196: No targets found

# %%
pprint(drugs)
# Out:
# [{'alternative_identifiers': {'BindingDB': '13530',
#                               'ChEBI': '45783',
#                               'ChEMBL': 'CHEMBL941',
#                               'ChemSpider': '5101',
#                               'Drugs.com': 'Drugs.com Drug Page',
#                               'Human Metabolome Database': 'HMDB0014757',
#                               'KEGG Drug': 'D01441',
#                               'PDBe Ligand': 'STI',
#                               'PharmGKB': 'PA10804',
#                               'PubChem Compound': '5291',
#                               'PubChem Substance': '46505055',
#                               'RxList': 'RxList Drug Page',
#                               'RxNav': '282388',
#                               'Therapeutic Targets Database': 'DNC001383',
#                               'Wikipedia': 'Imatinib',
#                               'ZINC': 'ZINC000019632618'},
#   'drug_bank_id': 'DB00619',
#   'smiles': 'CN1CCN(CC2=CC=C(C=C2)C(=O)NC2=CC(NC3=NC=CC(=N3)C3=CN=CC=C3)=C(C)C=C2)CC1',
#   'targets': [{'actions': ['Inhibitor'], 'gene_name': 'BCR'},
#               {'actions': ['Antagonist', 'Multitarget'], 'gene_name': 'KIT'},
#               {'actions': ['Inhibitor'], 'gene_name': 'RET'},
#               {'actions': ['Antagonist'], 'gene_name': 'NTRK1'},
#               {'actions': ['Antagonist'], 'gene_name': 'CSF1R'},
#               {'actions': ['Antagonist'], 'gene_name': 'PDGFRA'},
#               {'actions': ['Antagonist'], 'gene_name': 'DDR1'},
#               {'actions': ['Inhibitor'], 'gene_name': 'ABL1'},
#               {'actions': ['Antagonist'], 'gene_name': 'PDGFRB'}]},
#  {'alternative_identifiers': {'BindingDB': '50366816',
#                               'ChEBI': '421707',
#                               'ChEMBL': 'CHEMBL1380',
#                               'ChemSpider': '390063',
#                               'Drugs.com': 'Drugs.com Drug Page',
#                               'Human Metabolome Database': 'HMDB0015182',
#                               'KEGG Compound': 'C07624',
#                               'KEGG Drug': 'D07057',
#                               'PDBe Ligand': '1KX',
#                               'PDRhealth': 'PDRhealth Drug Page',
#                               'PharmGKB': 'PA448004',
#                               'PubChem Compound': '441300',
#                               'PubChem Substance': '46505718',
#                               'RxList': 'RxList Drug Page',
#                               'RxNav': '190521',
#                               'Therapeutic Targets Database': 'DAP000704',
#                               'Wikipedia': 'Abacavir',
#                               'ZINC': 'ZINC000002015928'},
#   'drug_bank_id': 'DB01048',
#   'smiles': 'NC1=NC2=C(N=CN2[C@@H]2C[C@H](CO)C=C2)C(NC2CC2)=N1',
#   'targets': [{'actions': ['Inhibitor'], 'gene_name': 'pol'}]},
#  {'alternative_identifiers': {'ChemSpider': '35147838'},
#   'drug_bank_id': 'DB14093',
#   'smiles': '[3H]C1C([3H])C2=CC(=O)C([3H])C([3H])[C@]2(C)[C@H]2CC[C@]3(C)[C@@H](O)CC[C@H]3[C@H]12'},
#  {'alternative_identifiers': {'BindingDB': '181146',
#                               'ChEBI': '16708',
#                               'ChEMBL': 'CHEMBL226345',
#                               'ChemSpider': '185',
#                               'Human Metabolome Database': 'HMDB0000034',
#                               'KEGG Compound': 'C00147',
#                               'KEGG Drug': 'D00034',
#                               'PDBe Ligand': 'ADE',
#                               'PharmGKB': 'PA448048',
#                               'PubChem Compound': '190',
#                               'PubChem Substance': '46507319',
#                               'RxNav': '290',
#                               'Therapeutic Targets Database': 'DAP000982',
#                               'Wikipedia': 'Adenine',
#                               'ZINC': 'ZINC000000000882'},
#   'drug_bank_id': 'DB00173',
#   'smiles': 'NC1=C2NC=NC2=NC=N1',
#   'targets': [{'gene_name': 'APRT'},
#               {'gene_name': 'mtnN'},
#               {'gene_name': 'ACACB'},
#               {'gene_name': 'ACP1'},
#               {'gene_name': 'PECR'},
#               {'gene_name': 'mutY'},
#               {'gene_name': 'ptd'},
#               {'gene_name': 'SRPK2'},
#               {'gene_name': 'ruvB'},
#               {'gene_name': 'MTAP'},
#               {'gene_name': 'cobT'}]},
#  {'alternative_identifiers': {'BindingDB': '50001885',
#                               'ChEBI': '8871',
#                               'ChEMBL': 'CHEMBL85',
#                               'ChemSpider': '4895',
#                               'Drugs.com': 'Drugs.com Drug Page',
#                               'Guide to Pharmacology': 'GtP Drug Page',
#                               'Human Metabolome Database': 'HMDB0005020',
#                               'KEGG Drug': 'D00426',
#                               'PDRhealth': 'PDRhealth Drug Page',
#                               'PharmGKB': 'PA451257',
#                               'PubChem Compound': '5073',
#                               'PubChem Substance': '46505850',
#                               'RxList': 'RxList Drug Page',
#                               'RxNav': '35636',
#                               'Therapeutic Targets Database': 'DAP000003',
#                               'Wikipedia': 'Risperidone',
#                               'ZINC': 'ZINC000000538312'},
#   'drug_bank_id': 'DB00734',
#   'smiles': 'CC1=C(CCN2CCC(CC2)C2=NOC3=C2C=CC(F)=C3)C(=O)N2CCCCC2=N1',
#   'targets': [{'actions': ['Antagonist'], 'gene_name': 'HTR2A'},
#               {'actions': ['Antagonist'], 'gene_name': 'DRD2'},
#               {'actions': ['Antagonist'], 'gene_name': 'ADRA1B'},
#               {'actions': ['Antagonist'], 'gene_name': 'ADRA2B'},
#               {'actions': ['Antagonist'], 'gene_name': 'ADRA1A'},
#               {'actions': ['Antagonist'], 'gene_name': 'ADRA2C'},
#               {'actions': ['Antagonist'], 'gene_name': 'HRH1'},
#               {'actions': ['Antagonist'], 'gene_name': 'HTR2C'},
#               {'actions': ['Antagonist'], 'gene_name': 'HTR1D'},
#               {'actions': ['Antagonist'], 'gene_name': 'HTR1A'},
#               {'actions': ['Antagonist'], 'gene_name': 'HTR7'}]},
#  {'alternative_identifiers': {'BindingDB': '50366824',
#                               'ChEBI': '63611',
#                               'ChEMBL': 'CHEMBL32',
#                               'ChemSpider': '134802',
#                               'Drugs.com': 'Drugs.com Drug Page',
#                               'Human Metabolome Database': 'HMDB0014363',
#                               'KEGG Compound': 'C07663',
#                               'KEGG Drug': 'D08237',
#                               'PDBe Ligand': 'MFX',
#                               'PDRhealth': 'PDRhealth Drug Page',
#                               'PharmGKB': 'PA450555',
#                               'PubChem Compound': '152946',
#                               'PubChem Substance': '46508509',
#                               'RxList': 'RxList Drug Page',
#                               'RxNav': '139462',
#                               'Therapeutic Targets Database': 'DAP000158',
#                               'Wikipedia': 'Moxifloxacin',
#                               'ZINC': 'ZINC000003826253'},
#   'drug_bank_id': 'DB00218',
#   'smiles': '[H][C@]12CN(C[C@@]1([H])NCCC2)C1=C(F)C=C2C(=O)C(=CN(C3CC3)C2=C1OC)C(O)=O',
#   'targets': [{'actions': ['Inhibitor'], 'gene_name': 'parC'},
#               {'actions': ['Inhibitor'], 'gene_name': 'gyrA'},
#               {'actions': ['Inhibitor'], 'gene_name': 'TOP2A'}]},
#  {'alternative_identifiers': {'PubChem Substance': '347910017'},
#   'drug_bank_id': 'DB05196',
#   'smiles': 'Not Available'},
#  {'alternative_identifiers': {'ChEBI': '135624',
#                               'ChEMBL': 'CHEMBL509924',
#                               'ChemSpider': '10128664',
#                               'PubChem Compound': '11954369',
#                               'PubChem Substance': '310265022',
#                               'RxNav': '3392',
#                               'Wikipedia': 'Diflucortolone',
#                               'ZINC': 'ZINC000004212939'},
#   'drug_bank_id': 'DB09095',
#   'smiles': '[H][C@@]12C[C@@H](C)[C@H](C(=O)CO)[C@@]1(C)C[C@H](O)[C@@]1(F)[C@@]2([H])C[C@H](F)C2=CC(=O)C=C[C@]12C',
#   'targets': [{'actions': ['Inducer'], 'gene_name': 'ANXA3'},
#               {'actions': ['Binder'], 'gene_name': 'NR3C1'}]},
#  {'alternative_identifiers': {'BindingDB': '50022787',
#                               'ChEBI': '18208',
#                               'ChEMBL': 'CHEMBL29',
#                               'ChemSpider': '5693',
#                               'Human Metabolome Database': 'HMDB0015186',
#                               'KEGG Compound': 'C05551',
#                               'KEGG Drug': 'D02336',
#                               'PDBe Ligand': 'PNN',
#                               'PharmGKB': 'PA450842',
#                               'PubChem Compound': '5904',
#                               'PubChem Substance': '46506778',
#                               'RxList': 'RxList Drug Page',
#                               'RxNav': '7980',
#                               'Therapeutic Targets Database': 'DNC001109',
#                               'Wikipedia': 'Benzylpenicillin',
#                               'ZINC': 'ZINC000003871701'},
#   'drug_bank_id': 'DB01053',
#   'smiles': '[H][C@]12SC(C)(C)[C@@H](N1C(=O)[C@H]2NC(=O)CC1=CC=CC=C1)C(O)=O',
#   'targets': [{'actions': ['Inhibitor'], 'gene_name': 'pbp3'},
#               {'actions': ['Substrate', 'Inhibitor'], 'gene_name': 'SLC22A8'},
#               {'actions': ['Substrate', 'Inhibitor'], 'gene_name': 'SLC15A1'},
#               {'actions': ['Inhibitor'], 'gene_name': 'SLC15A2'}]},
#  {'alternative_identifiers': {'BindingDB': '50350471',
#                               'ChEBI': '3489',
#                               'ChEMBL': 'CHEMBL1201195',
#                               'ChemSpider': '38311',
#                               'Human Metabolome Database': 'HMDB0014419',
#                               'KEGG Compound': 'C08103',
#                               'KEGG Drug': 'D00910',
#                               'PDBe Ligand': '4KO',
#                               'PharmGKB': 'PA164746819',
#                               'PubChem Compound': '42008',
#                               'PubChem Substance': '46504461',
#                               'RxNav': '2182',
#                               'Therapeutic Targets Database': 'DAP001179',
#                               'Wikipedia': 'Cefmetazole',
#                               'ZINC': 'ZINC000003830417'},
#   'drug_bank_id': 'DB00274',
#   'smiles': '[H][C@]12SCC(CSC3=NN=NN3C)=C(N1C(=O)[C@]2(NC(=O)CSCC#N)OC)C(O)=O',
#   'targets': [{'actions': ['Inhibitor'], 'gene_name': 'mecA'},
#               {'actions': ['Inhibitor'], 'gene_name': 'mrcA'},
#               {'actions': ['Inhibitor'], 'gene_name': 'mrcB'},
#               {'actions': ['Inhibitor'], 'gene_name': 'ftsI'},
#               {'actions': ['Inhibitor'], 'gene_name': 'dacA'},
#               {'actions': ['Inhibitor'], 'gene_name': 'dacC'}]}]

# %%
import json

with open("drugs.json", 'w') as json_file:
    json.dump(drugs, json_file)
